# %% [markdown]
# <a href="https://colab.research.google.com/github/MrSimple07/KMU_application/blob/main/prompt_stability_old_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 5.7 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from langchain.prompts import PromptTemplate

# tokenizer = AutoTokenizer.from_pretrained("Vikhrmodels/Vikhr-7B-instruct_merged")
# model = AutoModelForCausalLM.from_pretrained("Vikhrmodels/Vikhr-7B-instruct_merged")

tokenizer = AutoTokenizer.from_pretrained("ai-forever/mGPT")
model = AutoModelForCausalLM.from_pretrained("ai-forever/mGPT")

# %% [markdown]
# # Models
#
# 1. Vikhr
# 2. mGPT

# %%
from transformers import pipeline

#pipe = pipeline("text-generation", model="Vikhrmodels/Vikhr-7B-instruct_merged")

pipe = pipeline("text-generation", model="ai-forever/mGPT")
# Out:
# config.json:   0%|          | 0.00/710 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/4.64G [00:00<?, ?B/s]

# %%
from langchain.prompts import PromptTemplate

# TODO: add more templates here, including the original one
chegeka_prompt_collection = [
    PromptTemplate(input_variables=["topic", "text"],
                  template='''Вы участвуете в викторине "Что? Где? Когда?". Внимательно прочитайте вопрос из категории \
"{topic}" и ответьте на него. Обратите внимание на формат ответа: если он не указан в вопросе, \
то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно.
Вопрос: {text}
Ответ: '''), #1
    PromptTemplate(input_variables=["topic", "text"],
                  template= '''Прочитайте вопрос из категории "{topic}" и ответьте на него: {text}
Ответ: '''), #2
    PromptTemplate(input_variables=["topic", "text"],
                   template='''Вы участвуете в викторине "Что? Где? Когда?". Внимательно прочитайте вопрос из категории "{topic}" и ответьте на него. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно.
Вопрос: {text}
Ответ: '''), #3
    PromptTemplate(input_variables=["topic", "text"],
                   template='''Вы участвуете в викторине "Что? Где? Когда?". Прочитайте внимательно вопрос из категории "{topic}" и дайте точный ответ. Вопрос: {text}
Ответ: '''), #4
     PromptTemplate(input_variables=["topic", "text"],
                   template='''Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "{text}". Ваш ответ: {topic}
Ответ: ''') #5
#     PromptTemplate(input_variables=["topic", "text"],
#                    template='''Подумайте и дайте точный ответ на вопрос из категории "{topic}": {text}
# Ответ: '''), #6
#      PromptTemplate(input_variables=["topic", "text"],
#                    template='''Ваш вопрос из категории "{topic}": {text}. Внимание, у вас ограниченное время!
# Ответ: '''), #7
#     PromptTemplate(input_variables=["topic", "text"],
#                    template='''Подумайте быстро! Что бы вы ответили на вопрос из категории "{topic}": {text}?
# Ответ: '''), #8
#     PromptTemplate(input_variables=["topic", "text"],
#                    template='''На вас лежит ответственная задача отгадать вопрос из раздела "{topic}": {text}.
# Ответ: '''), #9
#     PromptTemplate(input_variables=["topic", "text"],
#                    template='''Спрятанный вопрос из раздела "{topic}" ждет вашего ответа: {text}
# Ответ: ''') #10
]

# %%
# TODO: create a collection of sampled tasks

chegeka_task_collection = [
    {'text':'Продолжение этого фильма Евгения Матвеева называется', 'topic': 'Любовь'},
    {'text': 'С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу.', 'topic': 'Гласные - только "А"'},
    {'text': 'По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей. Одна часть — знания и опыт." А что составляет остальные девять?', 'topic': 'Восток - дело тонкое'},
    {'text': 'По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг.', 'topic': 'Кланы'},
    {'text': 'На девятерной вистуют только эти 2 категории людей', 'topic': 'Нет хода - не вистуй!'},
    {'text': 'Эпиграф к книге "Корпорация М.И.Ф." Асприна звучит так: "Главное — не злоупотреблять...". Чем?', 'topic': 'Миф'},
    {'text': 'Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя.', 'topic': '-УРИ-.'},
    {'text': 'Именно столько морей омывает берега Италии.', 'topic': 'Италия'},
    {'text': 'Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет".', 'topic': 'ФИЛОСОФИЯ'},
    {'text': 'ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг.', 'topic': 'Орехи'}
]

chegeka_collection_answers = [
    {'answer': 'Любовь земная'},
    {'answer': 'Сарданапал'},
    {'answer': 'Молчание'},
    {'answer': 'Ку-клукс-клан (греч. "киклос")'},
    {'answer': 'Попы и студенты (попы от жадности, а студенты — от бедности :-))'},
    {'answer': 'Эпиграфами'},
    {'answer': 'Василий Суриков'},
    {'answer': 'Пять (Ионическое, Тирренское, Лигурийское, Адриатическое и Средиземное)'},
    {'answer': 'Томас Мор ("Утопия")'},
    {'answer': 'Мускатный'}
]

# %%
import pandas as pd

# you should use generation method with temperature, i put pipeline here just for example
def process_texts(prompt_collection, task_collection, pipe, temperature = 0):
    results = []

    for task in task_collection:
        '================ Starting new task ================='
        for prompt in prompt_collection:
            # TODO: save all results to csv dataframe (question, text, prompt, answer)

            generated_text = pipe(prompt.format(**task), return_full_text=False, max_new_tokens=100)[0]['generated_text']
            results.append({'question': task['text'], 'prompt': prompt.format(**task), 'answer': task.get('answer', None), 'generated_text': generated_text})

            df_results = pd.DataFrame(results)
            df_results.to_csv('generated_results.csv', index=False)

            # for instruction models may be special tokens that should be included in the prompt
            print(pipe(prompt.format(**task), return_full_text=False, max_new_tokens=100))

# %%
import pandas as pd

# you should use generation method with temperature, i put pipeline here just for example
def process_texts(prompt_collection, task_collection, pipe):
    results = []

    for task in task_collection:
        '================ Starting new task ================='
        for prompt in prompt_collection:
            # TODO: save all results to csv dataframe (question, text, prompt, answer)

            generated_text = pipe(prompt.format(**task), return_full_text=False, max_new_tokens=100)[0]['generated_text']
            results.append({'question': task['text'], 'prompt': prompt.format(**task), 'answer': task.get('answer', None), 'generated_text': generated_text})

            df_results = pd.DataFrame(results)
            df_results.to_csv('generated_results.csv', index=False)

            # for instruction models may be special tokens that should be included in the prompt
            print(pipe(prompt.format(**task), return_full_text=False, max_new_tokens=100))

# %%
process_texts(chegeka_prompt_collection, chegeka_task_collection, pipe)
# Out:
# [{'generated_text': '________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________'}]
# [{'generated_text': '________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________'}]
# ...

# %% [markdown]
# # TinyLlama

# %%
from transformers import pipeline
pipe = pipeline("text-generation", model="TinyLlama/TinyLlama-1.1B-Chat-v1.0")
# Out:
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]

# %%
process_texts(chegeka_prompt_collection, chegeka_task_collection, pipe)
# Out:
# [{'generated_text': '\n\n"Что? Где? Когда?"\n\nВнимательно прочитайте ответ отвечающего на вопрос.\n\nВопрос: Как вы понимаете, что происходит в фильме Евгения Матвеева "Что? Где? Когда?"\nОтвет: \n\n"Любовь"\n\nВнимательно прочитайте ответ отвечающего на вопрос'}]
# [{'generated_text': '\n\nДа, продолжение этого фильма Евгения Матвеева называется "Долгие годы".'}]
# [{'generated_text': '\n\n"Что? Где? Когда?"\n\nВнимательно прочитайте ответ отвечающего на вопрос.\n\nВопрос: Как вы понимаете, что происходит в фильме Евгения Матвеева "Что? Где? Когда?"\nОтвет: \n\n"Любовь"\n\nВнимательно прочитайте ответ отвечающего на вопрос'}]
# [{'generated_text': '1. "Что? Где? Когда?"\n2. "Когда?"\n3. "Когда?"\n4. "Когда?"\n5. "Когда?"\n6. "Когда?"\n7. "Когда?"\n8. "Когда?"\n9. "Когда?"\n10. "Когда?"\n11. "Когда?"\n12. "Когда?"\n13. "Когда?"'}]
# ...

# %%
# TODO
# 1. measure answer correctness (metric from original benchmark, the same as they measure) for each of the tasks with different prompts


# 2. measure answer variability (metric(s) is up to you to propose) for a task depending on a prompt


# ----- upper two tasks for initial KMU application
# 3. take LIME (or other method for interpreting the dependence of the answer on input) and analyze why answers are different

# %% [markdown]
# |question|prompt|answer|generated\_text|
# |---|---|---|---|
# |Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Миф" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?
# Ответ: ||1\. Главное — не злоупотреблять\.
# 2\. Злоупотреблять — это злоупотребление\.
# 3\. Главное — не злоупотреблять\.
# 4\. Злоупотреблять — это злоупотребление\.
# 5\. Главное — не злоупотреблять\.
# 6\. Злоупотреблять|
# |Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?|Прочитайте вопрос из категории "Миф" и ответьте на него: Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?
# Ответ: ||1\. "Главное — не злоупотреблять\.\.\."\. Это абсолютно правильный вариант\.
# 2\. "Главное — не злоупотреблять\.\.\."\. Это неправильный вариант\.
# 3\. "Главное — не злоупотреблять\.\.\."\. Это неправильный вариант\.
# 4\. "Главное — не злоупо|
# |Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Миф" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?
# Ответ: ||1\. Главное — не злоупотреблять\.
# 2\. Злоупотреблять — это злоупотребление\.
# 3\. Главное — не злоупотреблять\.
# 4\. Злоупотреблять — это злоупотребление\.
# 5\. Главное — не злоупотреблять\.
# 6\. Злоупотреблять|
# |Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "Миф" и дайте точный ответ\. Вопрос: Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?
# Ответ: ||1\. Главное — не злоупотреблять\.
# 2\. Злоупотреблять — это злоупотребление\.
# 3\. Главное — не злоупотреблять\.
# 4\. Злоупотреблять — это злоупотребление\.
# 5\. Главное — не злоупотреблять\.
# 6\. Злоупотреблять|
# |Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "Эпиграф к книге "Корпорация М\.И\.Ф\." Асприна звучит так: "Главное — не злоупотреблять\.\.\."\. Чем?"\. Ваш ответ: Миф
# Ответ: ||1\. Главное — не злоупотреблять\.\.\.
#
# 2\. Чем?
# Ответ: 2\. Главное — не злоупотреблять\.\.\.
#
# 3\. Чем?
# Ответ: 3\. Главное — не злоупотреблять\.\.\.
#
# 4\. Чем?
# Ответ: 4\. Главное — не злоупотреблять\.\.\.
#
# 5\.|
# |ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Орехи" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.
# Ответ: ||1\. The fruit is so important to the export trade of Grenada that it has even made it onto the country's flag\.
# 2\. The fruit is so important to the export trade of Grenada that it has even made it onto the country's flag\.
# 3\. The fruit is so important to the export trade of Grenada that it has even made it onto the country's flag\.
# 4\. The fruit is so important to the export trade of Grenada that it|
# |ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.|Прочитайте вопрос из категории "Орехи" и ответьте на него: ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.
# Ответ: ||1\. The question is about oranges\.
# 2\. The oranges are exported from Grenada\.
# 3\. The oranges are so important that they have even made it onto the country's flag\.
# 4\. The question is about the oranges\.
# 5\. The question is about the oranges\.
# 6\. The question is about the oranges\.
# 7\. The question is about the oranges\.
# 8\. The question is about the oranges\.
# |
# |ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Орехи" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.
# Ответ: ||1\. The fruit is so important to the export trade of Grenada that it has even made it onto the country's flag\.
# 2\. The fruit is so important to the export trade of Grenada that it has even made it onto the country's flag\.
# 3\. The fruit is so important to the export trade of Grenada that it has even made it onto the country's flag\.
# 4\. The fruit is so important to the export trade of Grenada that it|
# |ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "Орехи" и дайте точный ответ\. Вопрос: ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.
# Ответ: ||1\. "Орехи" - это до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.
# 2\. "Орехи" - это до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.
# 3\. "Орехи" - это до такой степени важной частью экспорта Гренады,|
# |ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\.|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "ЭТОТ ОРЕХ является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\."\. Ваш ответ: Орехи
# Ответ: ||1\. "Этот орех является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\."
#
# 2\. "Этот орех является до такой степени важной частью экспорта Гренады, что даже попал на ее флаг\."
#
# 3\. "Этот орех является до такой степени важной частью экспор|
# |С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Гласные - только "А"" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\.
# Ответ: ||1\. Богатый вельмож, 2\. Ленивый вельмож\.
# Вопрос: В каком городе жил Нина, 33-м потомком Державина?
# Ответ: В городе, где жил Нина, 33-м потомком Державина, не указан\.
# Вопрос: В каком городе жил Нина, 33-м по|
# |С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\.|Прочитайте вопрос из категории "Гласные - только "А"" и ответьте на него: С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\.
# Ответ: ||33-м потомком Нины, Державина сравнивает богатого и ленивого вельможу\.|
# |С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Гласные - только "А"" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\.
# Ответ: ||1\. Богатый вельмож, 2\. Ленивый вельмож\.
# Вопрос: В каком городе жил Нина, 33-м потомком Державина?
# Ответ: В городе, где жил Нина, 33-м потомком Державина, не указан\.
# Вопрос: В каком городе жил Нина, 33-м по|
# |С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\.|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "Гласные - только "А"" и дайте точный ответ\. Вопрос: С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\.
# Ответ: ||33-м потомком Нины Державина\.|
# |С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\.|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "С ЭТИМ ЧЕЛОВЕКОМ, 33-м потомком Нина, Державин сравнивает богатого и ленивого вельможу\."\. Ваш ответ: Гласные - только "А"
# Ответ: ||33-м потомком Нины Державина является богатый и ленивый вельможа\.|
# |Продолжение этого фильма Евгения Матвеева называется|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Любовь" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Продолжение этого фильма Евгения Матвеева называется
# Ответ: ||
#
# "Что? Где? Когда?"
#
# Внимательно прочитайте ответ отвечающего на вопрос\.
#
# Вопрос: Как вы понимаете, что происходит в фильме Евгения Матвеева "Что? Где? Когда?"
# Ответ:
#
# "Любовь"
#
# Внимательно прочитайте ответ отвечающего на вопрос|
# |Продолжение этого фильма Евгения Матвеева называется|Прочитайте вопрос из категории "Любовь" и ответьте на него: Продолжение этого фильма Евгения Матвеева называется
# Ответ: ||
#
# Да, продолжение этого фильма Евгения Матвеева называется "Долгие годы"\.|
# |Продолжение этого фильма Евгения Матвеева называется|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Любовь" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Продолжение этого фильма Евгения Матвеева называется
# Ответ: ||
#
# "Что? Где? Когда?"
#
# Внимательно прочитайте ответ отвечающего на вопрос\.
#
# Вопрос: Как вы понимаете, что происходит в фильме Евгения Матвеева "Что? Где? Когда?"
# Ответ:
#
# "Любовь"
#
# Внимательно прочитайте ответ отвечающего на вопрос|
# |Продолжение этого фильма Евгения Матвеева называется|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "Любовь" и дайте точный ответ\. Вопрос: Продолжение этого фильма Евгения Матвеева называется
# Ответ: ||1\. "Что? Где? Когда?"
# 2\. "Когда?"
# 3\. "Когда?"
# 4\. "Когда?"
# 5\. "Когда?"
# 6\. "Когда?"
# 7\. "Когда?"
# 8\. "Когда?"
# 9\. "Когда?"
# 10\. "Когда?"
# 11\. "Когда?"
# 12\. "Когда?"
# 13\. "Когда?"|
# |Продолжение этого фильма Евгения Матвеева называется|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "Продолжение этого фильма Евгения Матвеева называется"\. Ваш ответ: Любовь
# Ответ: ||1\. Любовь
#
# 2\. Любовь
#
# 3\. Любовь
#
# 4\. Любовь
#
# 5\. Любовь
#
# 6\. Любовь
#
# 7\. Любовь
#
# 8\. Любовь
#
# 9\. Любовь
#
# 10\. Любовь
#
# 11\. Любовь
#
# 12\. Любовь
#
# 13\. Любовь
#
# 14\. Любов|
# |По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Кланы" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\.
# Ответ: ||1\. В 1990-х годах, когда в стране начали появляться первые экологические движения, в качестве названия организации была выбрана словосочетание "Экологическая организация" \(ECO\)\.
# 2\. В 2000-х годах, когда в стране начали появляться первые движения за защиту окружающей среды, в качестве названия организации была|
# |По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\.|Прочитайте вопрос из категории "Кланы" и ответьте на него: По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\.
# Ответ: ||1\. The organization is named after the Greek word for circle\.|
# |По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Кланы" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\.
# Ответ: ||1\. В 1990-х годах, когда в стране начали появляться первые экологические движения, в качестве названия организации была выбрана словосочетание "Экологическая организация" \(ECO\)\.
# 2\. В 2000-х годах, когда в стране начали появляться первые движения за защиту окружающей среды, в качестве названия организации была|
# |По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\.|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "Кланы" и дайте точный ответ\. Вопрос: По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\.
# Ответ: ||1\. "What is the name of this organization that comes from the Greek word for circle?"
# 2\. "What is the name of this organization that comes from the Greek word for circle?"
# 3\. "What is the name of this organization that comes from the Greek word for circle?"
# 4\. "What is the name of this organization that comes from the Greek word for circle?"
# 5\. "What is the name of this organization that comes from the Greek word for circle?"
# |
# |По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\.|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "По одной из версий, начало названия ЭТОЙ ОРГАНИЗАЦИИ происходит от греческого слова, обозначающего круг\."\. Ваш ответ: Кланы
# Ответ: ||1\. Кланы|
# |По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Восток - дело тонкое" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?
# Ответ: ||1\. Смысл: знание и опыт\.
# 2\. Смысл: знание и опыт\.
# 3\. Смысл: знание и опыт\.
# 4\. Смысл: знание и опыт\.
# 5\. Смысл: знание и опыт\.
# 6\. Смысл: знание и опыт\.
# 7\. Смысл: знание и|
# |По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?|Прочитайте вопрос из категории "Восток - дело тонкое" и ответьте на него: По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?
# Ответ: ||1\. Наука — знание, которое позволяет избегать ошибок и не допускать их в будущем\.
# 2\. Опыт — знание, которое позволяет избегать ошибок в настоящем\.
# 3\. Смысл — знание, которое позволяет избегать ошибок в будущем\.
# 4\. Смысл — знание, кото|
# |По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Восток - дело тонкое" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?
# Ответ: ||1\. Смысл: знание и опыт\.
# 2\. Смысл: знание и опыт\.
# 3\. Смысл: знание и опыт\.
# 4\. Смысл: знание и опыт\.
# 5\. Смысл: знание и опыт\.
# 6\. Смысл: знание и опыт\.
# 7\. Смысл: знание и|
# |По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "Восток - дело тонкое" и дайте точный ответ\. Вопрос: По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?
# Ответ: ||1\. Опыт: опыт — это знание, которое вы получаете в результате наблюдения и опыта\.
# 2\. Смысл: смысл — это знание, которое вы получаете в результате понимания и анализа\.
# 3\. Стиль: стиль — это знание, которое вы получаете в результате анализа и понимания\.
# 4\. Сек|
# |По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "По мнению древнего мудреца Рюхейб-бин-Верда: "Мудрость состоит из 10 частей\. Одна часть — знания и опыт\." А что составляет остальные девять?"\. Ваш ответ: Восток - дело тонкое
# Ответ: ||1\. Восток - дело тонкое
#
# 2\. Восток - дело тонкое
#
# 3\. Восток - дело тонкое
#
# 4\. Восток - дело тонкое
#
# 5\. Восток - дело тонкое
#
# 6\. Восток - дело тонкое
#
# 7\. Восток - дело тонкое
#
# 8\.|
# |На девятерной вистуют только эти 2 категории людей|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Нет хода - не вистуй\!" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: На девятерной вистуют только эти 2 категории людей
# Ответ: ||1\. В какой из категорий людей на девятерной висту вы выбираете?
# 2\. В какой из категорий людей вы выбираете?
# 3\. В какой из категорий людей вы выбираете?
# 4\. В какой из категорий людей вы выбираете?
# 5\. В какой из категорий людей вы выбираете?
# 6\. В какой из катего|
# |На девятерной вистуют только эти 2 категории людей|Прочитайте вопрос из категории "Нет хода - не вистуй\!" и ответьте на него: На девятерной вистуют только эти 2 категории людей
# Ответ: ||1\. "Нет хода - не вистуй\!" - это не ошибка, а просто неверный ответ\. 2\. "Нет хода - не вистуй\!" - это не ошибка, а просто неверный ответ\. 3\. "Нет хода - не вистуй\!" - это не ошибка, а просто неверный ответ\. 4\. "Нет хода - не ви|
# |На девятерной вистуют только эти 2 категории людей|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Нет хода - не вистуй\!" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: На девятерной вистуют только эти 2 категории людей
# Ответ: ||1\. В какой из категорий людей на девятерной висту вы выбираете?
# 2\. В какой из категорий людей вы выбираете?
# 3\. В какой из категорий людей вы выбираете?
# 4\. В какой из категорий людей вы выбираете?
# 5\. В какой из категорий людей вы выбираете?
# 6\. В какой из катего|
# |На девятерной вистуют только эти 2 категории людей|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "Нет хода - не вистуй\!" и дайте точный ответ\. Вопрос: На девятерной вистуют только эти 2 категории людей
# Ответ: ||1\. "Что" - это все, что происходит в жизни\. 2\. "Где" - это место, где происходит это\. 3\. "Когда" - это время, когда происходит это\. 4\. "Что" - это все, что происходит в жизни\. 5\. "Где" - это место, где происходит это\. 6\. "Когда" - это время, когда происходит это\. 7\.|
# |На девятерной вистуют только эти 2 категории людей|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "На девятерной вистуют только эти 2 категории людей"\. Ваш ответ: Нет хода - не вистуй\!
# Ответ: ||2 категории людей не вистуют на девятерной висте\.|
# |Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "-УРИ-\." и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\.
# Ответ: ||1\. "Первая версия" Храма Христа Спасителя - это роспись, которая была сделана в 1986 году\.
# 2\. "Кроме известных исторических полотен" - это некорректный ответ\. В вопросе указаны известные исторические полотна, а не "которые" известны\.
# 3\. ЕГО кисти принадлежат - это|
# |Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\.|Прочитайте вопрос из категории "-УРИ-\." и ответьте на него: Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\.
# Ответ: ||1\. "Первая версия" Храма Христа Спасителя - это неизвестная и неизвестная\.
# 2\. ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя - это неизвестная и неизвестная\.
# 3\. ЕГО кисти принадлежат росписи "первой версии" Храма Христа С|
# |Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "-УРИ-\." и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\.
# Ответ: ||1\. "Первая версия" Храма Христа Спасителя - это роспись, которая была сделана в 1986 году\.
# 2\. "Кроме известных исторических полотен" - это некорректный ответ\. В вопросе указаны известные исторические полотна, а не "которые" известны\.
# 3\. ЕГО кисти принадлежат - это|
# |Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\.|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "-УРИ-\." и дайте точный ответ\. Вопрос: Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\.
# Ответ: ||1\. "Первая версия" Храма Христа Спасителя - это не историческая полотнище, а рисунок, на котором были написаны первые 1000-1500 фрагментов из 15000-18000 фрагментов, которые были написаны в период с 1907 по 1917 год\.
# 2|
# |Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\.|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\."\. Ваш ответ: -УРИ-\.
# Ответ: ||1\. "Кроме известных исторических полотен, ЕГО кисти принадлежат росписи "первой версии" Храма Христа Спасителя\."|
# |Именно столько морей омывает берега Италии\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Италия" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Именно столько морей омывает берега Италии\.
# Ответ: ||1\.1 миллиона км²
#
# 2\. В какой стране находится столица Италии?
# Ответ: В Италии стоит столица - Рим\.
#
# 3\. В каком городе находится столица Италии?
# Ответ: В Италии стоит столица - Рим\.
#
# 4\. В каком городе находится столица Италии?
# Ответ: В Италии стоит столи|
# |Именно столько морей омывает берега Италии\.|Прочитайте вопрос из категории "Италия" и ответьте на него: Именно столько морей омывает берега Италии\.
# Ответ: ||1\. The Mediterranean Sea is the largest body of water in the world\.
# 2\. The Mediterranean Sea is the only sea that is surrounded by three continents\.
# 3\. The Mediterranean Sea is the only sea that is surrounded by three countries\.
# 4\. The Mediterranean Sea is the only sea that is surrounded by three countries that are all members of the European Union\.
# 5\. The Mediterranean Sea is the only sea that is surrounded by three|
# |Именно столько морей омывает берега Италии\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "Италия" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Именно столько морей омывает берега Италии\.
# Ответ: ||1\.1 миллиона км²
#
# 2\. В какой стране находится столица Италии?
# Ответ: В Италии стоит столица - Рим\.
#
# 3\. В каком городе находится столица Италии?
# Ответ: В Италии стоит столица - Рим\.
#
# 4\. В каком городе находится столица Италии?
# Ответ: В Италии стоит столи|
# |Именно столько морей омывает берега Италии\.|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "Италия" и дайте точный ответ\. Вопрос: Именно столько морей омывает берега Италии\.
# Ответ: ||1000\.|
# |Именно столько морей омывает берега Италии\.|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "Именно столько морей омывает берега Италии\."\. Ваш ответ: Италия
# Ответ: ||1\. "Что?"
# 2\. "Где?"
# 3\. "Когда?"
# 4\. "Именно столько морей омывает берега Италии\."
#
# Ваш ответ: 1\. "Что?"
# 2\. "Где?"
# 3\. "Когда?"
# 4\. "Именно столько морей омывает берега Италии\."|
# |Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "ФИЛОСОФИЯ" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\.
# Ответ: ||1\. "Похвала глупости" - это книга Роттердамского, посвящённая глупости\.
# 2\. В 1935 году церковь канонизировала Роттердамского, хотя он написал книгу о "месте, которого нет"\.
# 3\. "Место, которого нет" - это название книги Роттердамского\.
# 4\.|
# |Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\.|Прочитайте вопрос из категории "ФИЛОСОФИЯ" и ответьте на него: Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\.
# Ответ: ||1\. Эразм Роттердамский посвятил свою книгу "Похвала глупости" своему другу, а не своему имени\. 2\. Церковь канонизировала его в 1935 году, хотя он написал книгу о "месте, которого нет"\. 3\. Эразм Роттердамский написал книгу о "месте, которого не|
# |Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\.|Вы участвуете в викторине "Что? Где? Когда?"\. Внимательно прочитайте вопрос из категории "ФИЛОСОФИЯ" и ответьте на него\. Обратите внимание на формат ответа: если он не указан в вопросе, то запишите только слово или фразу, отвечающую на вопрос, никаких дополнительных рассуждений приводить не нужно\.
# Вопрос: Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\.
# Ответ: ||1\. "Похвала глупости" - это книга Роттердамского, посвящённая глупости\.
# 2\. В 1935 году церковь канонизировала Роттердамского, хотя он написал книгу о "месте, которого нет"\.
# 3\. "Место, которого нет" - это название книги Роттердамского\.
# 4\.|
# |Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\.|Вы участвуете в викторине "Что? Где? Когда?"\. Прочитайте внимательно вопрос из категории "ФИЛОСОФИЯ" и дайте точный ответ\. Вопрос: Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\.
# Ответ: ||1\. "Что" - вопрос\.
# 2\. "Где" - ответ\. В книге "Похвала глупости" Роттердамский пишет, что он жил в 1912 году в городе Энсхеде, но в 1913 году переехал в Энсхеде, где и жил до своей смерти в 1919 году\.
# 3\.|
# |Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\.|Угадайте, в какой категории из "Что? Где? Когда?" относится следующий вопрос: "Именно ему Эразм Роттердамский посвятил свою книгу "Похвала глупости", а церковь канонизировала его в 1935 году, хотя он и написал книгу о "месте, которого нет"\."\. Ваш ответ: ФИЛОСОФИЯ
# Ответ: ||1\. "Похвала глупости" посвящена в первую очередь вопросу о том, где и когда Роттердамский написал книгу\. 2\. В книге "Похвала глупости" Роттердамский рассказывает о том, где и когда он написал книгу\. 3\. В книге "Похвала глупости" Роттердамский|
